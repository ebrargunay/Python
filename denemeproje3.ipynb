# %% [markdown]
# <a href="https://colab.research.google.com/github/ebrargunay/Python/blob/main/denemeproje3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if puan > 60:
  print("Tebrikler.Testi başarıyla geçtiniz.")
else:
  print("Testi geçemediniz. Yeniden başlamak ister misiniz?")
  yenidenbaşla

# %%
print("The Office dizisi ile ilgili kısa test uygulamasına hoşgeldiniz.\nKarşınıza çıkan ifadelere evet yada hayır olarak cevap veriniz.\nBakalım gerçekten The Office hayranı mısınız :)")

  sorular = ["The Office dizisi dokuz sezondur.","The Office dizisindeki şirket bir tarım şirketidir.","Dunder Mifflin'in müdürü Michael Scott'tır.","Michael, Jan ile evlenmiştir.","Toby, Michael'ın en sevdiği çalışandır."]
  cevaplar = ["evet","hayır","evet","hayır","hayır"]
  puan = 0

  print("1. " + sorular [0])
  cevap1 = input("Cevabınız: ")
  if  cevap1 == cevaplar[0]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("2. " + sorular [1])
  cevap2 = input("Cevabınız: ")
  if  cevap2 == cevaplar[1]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("3. " + sorular [2])
  cevap3 = input("Cevabınız: ")
  if  cevap3 == cevaplar[2]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("4. " + sorular [3])
  cevap4 = input("Cevabınız: ")
  if  cevap4 == cevaplar[3]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("5. " + sorular [4])
  cevap5 = input("Cevabınız: ")
  if  cevap5 == cevaplar[4]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))


  doğrular = 0
  yanlıslar = 0

  if cevap1 == cevaplar[0]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap2 == cevaplar[1]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap3 == cevaplar[2]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap4 == cevaplar[3]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap5 == cevaplar[4]:
    doğrular +=1
  else:
    yanlıslar +=1


  print("Doğru cevapladığınız soru sayısı: " + str(doğrular))
  print("Yanlış cevapladığınız soru sayısı: " + str(yanlıslar))

  if puan > 60:
    print("Tebrikler.Testi başarıyla geçtiniz.Puanınız: "+ str(puan) )
  else:
    print("Puanınız: " + str(puan) + " Testi geçemediniz. ") + input("Yeniden başlamak ister misiniz?")
# Out:
#   File "<ipython-input-19-1db3e5305630>", line 91
#     return "tekrarla"
#                      ^
# IndentationError: expected an indented block

# %%
doğrular = 0
yanlıslar = 0

if cevap1 == cevaplar[0]:
  doğrular +=1
else:
  yanlıslar +=1

if cevap2 == cevaplar[1]:
  doğrular +=1
else:
  yanlıslar +=1

if cevap3 == cevaplar[2]:
  doğrular +=1
else:
  yanlıslar +=1

if cevap4 == cevaplar[3]:
  doğrular +=1
else:
  yanlıslar +=1

if cevap5 == cevaplar[4]:
  doğrular +=1
else:
  yanlıslar +=1

# %%
print("The Office dizisi ile ilgili kısa test uygulamasına hoşgeldiniz.\nKarşınıza çıkan ifadelere evet yada hayır olarak cevap veriniz.\nBakalım gerçekten The Office hayranı mısınız :)")
while True:
  sorular = ["The Office dizisi dokuz sezondur.","The Office dizisindeki şirket bir tarım şirketidir.","Dunder Mifflin'in müdürü Michael Scott'tır.","Michael, Jan ile evlenmiştir.","Toby, Michael'ın en sevdiği çalışandır."]
  cevaplar = ["evet","hayır","evet","hayır","hayır"]
  puan = 0

  print("1. " + sorular [0])
  cevap1 = input("Cevabınız: ")
  if  cevap1 == cevaplar[0]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("2. " + sorular [1])
  cevap2 = input("Cevabınız: ")
  if  cevap2 == cevaplar[1]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("3. " + sorular [2])
  cevap3 = input("Cevabınız: ")
  if  cevap3 == cevaplar[2]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("4. " + sorular [3])
  cevap4 = input("Cevabınız: ")
  if  cevap4 == cevaplar[3]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))

  print("5. " + sorular [4])
  cevap5 = input("Cevabınız: ")
  if  cevap5 == cevaplar[4]:
    print("Doğru bildiniz.")
    puan += 20
  else:
    print("Yanlış cevap.")
  print("Puanınız :" + str(puan))


  doğrular = 0
  yanlıslar = 0

  if cevap1 == cevaplar[0]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap2 == cevaplar[1]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap3 == cevaplar[2]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap4 == cevaplar[3]:
    doğrular +=1
  else:
    yanlıslar +=1

  if cevap5 == cevaplar[4]:
    doğrular +=1
  else:
    yanlıslar +=1


  print("Doğru cevapladığınız soru sayısı: " + str(doğrular))
  print("Yanlış cevapladığınız soru sayısı: " + str(yanlıslar))

  if puan > 60:
    print("Tebrikler.Testi başarıyla geçtiniz.Puanınız: "+ str(puan) )
    break
  else:
    print("Puanınız: " + str(puan) + " Testi geçemediniz.")
    print(input("Yeniden başlamak ister misiniz?"))
    cevap = "evet"
  if cevap == "hayır":
    break
# Out:
#   File "<ipython-input-40-ae83e2e39a98>", line 92
#     elif cevap == "hayır":
#        ^
# SyntaxError: invalid syntax
